# %% [markdown]
# <p style="font-size:200%; font-weight:bold"> Connected Wallets </p>
#
# - Author: Yichen Luo
# - Date: 20220803

# %% [markdown]
# - Contracts exist in the root list.
# - Should we remove null address.

# %%
from web3 import Web3, EthereumTesterProvider
from hexbytes import HexBytes
import pandas as pd
import time
import os
import requests
import datetime
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell

pd.set_option('max_colwidth', 100)
pd.set_option('display.max_columns', 100)
InteractiveShell.ast_node_interactivity = 'all'
os.getcwd()

RD = '/home/team_defi/02_rdata/'
WD = '/home/team_defi/03_wdata/'
RES = '/home/team_defi/04_result/'
# Out:
# '/home/team_defi/01_code'

# %% [markdown]
# # Root Account List

# %%
# chains = ['binance', 'avalanche', 'fantom', 'polygon']

# for chain in chains:
#     df = pd.read_csv(f'{WD}root/root_{chain}_unwrapped.csv').drop_duplicates('root', keep='last')['root']
#     df = df.reset_index().drop(columns='index')
#     df['normal_token'] = -1
#     df['nft_token'] = -1
#     df
#     df.to_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv', index=False)
# Out:
#                                             root  normal_token  nft_token
# 0     0xf4784c0ea2b64359a5b0d94129e28a81cf80a9d6            -1         -1
# 1     0x7431d90db56582a6c6a4c0eb375db20289d2264c            -1         -1
# 2     0x57b85ec48b6c8acf7fc396d459d1c71f8a6064bf            -1         -1
# 3     0x180d285dd9a4fec0d95ed94436f722f0ff01cfb2            -1         -1
# 4     0xa10fe5280e10e0a43e083098763bc02696d00119            -1         -1
# ...                                          ...           ...        ...
# 5973  0x0001233a134331a3761df381ba4aa303d7c5f24f            -1         -1
# 5974  0x96592ef0f1196652a26fa629ee4051e2becb1360            -1         -1
# 5975  0x65104a0079753481b8780f2379bf680248a1fd9e            -1         -1
# 5976  0xe9424ea8f28ae4cd3e623bdc24bd2026b0252d84            -1         -1
# 5977  0x3560db9e2d217bc4ec48e62c6a31c7ad3f4c350e            -1         -1
#
# [5978 rows x 3 columns]
# ...

# %% [markdown]
# # Web Crawler

# %%
chains = ['ethereum', 'binance', 'avalanche', 'fantom', 'polygon']
token_types = ['normal_token', 'nft_token']

for chain in chains:
    for token_type in token_types:
        
        lst = pd.read_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv')
        done = lst.loc[(lst[token_type] != -1)].shape[0]
        total = lst.shape[0]

        for idx, row in lst.loc[(lst[token_type] == -1)].iterrows():

            root = row['root']

            if (chain == 'ethereum')&(token_type == 'normal_token'):
                url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock=0\
&endblock=99999999\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

            if (chain == 'ethereum')&(token_type == 'nft_token'):     
                url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock=0\
&endblock=99999999\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

            if (chain == 'binance')&(token_type == 'normal_token'):    
                url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock=0\
&endblock=999999999\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

            if (chain == 'binance')&(token_type == 'nft_token'): 
                url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock=0\
&endblock=999999999\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

            if (chain == 'avalanche')&(token_type == 'normal_token'): 
                url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock=0\
&endblock=999999999\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

            if (chain == 'avalanche')&(token_type == 'nft_token'):     
                url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock=0\
&endblock=999999999\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

            if (chain == 'fantom')&(token_type == 'normal_token'):    
                url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&startblock=0\
&endblock=99999999\
&page=1\
&offset=10000\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

            if (chain == 'fantom')&(token_type == 'nft_token'):  
                url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&startblock=0\
&endblock=99999999\
&page=1\
&offset=10000\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

            if (chain == 'polygon')&(token_type == 'normal_token'): 
                url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&startblock=0\
&endblock=99999999\
&page=1\
&offset=10000\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'

            if (chain == 'polygon')&(token_type == 'nft_token'): 
                url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&startblock=0\
&endblock=99999999\
&page=1\
&offset=10000\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'    

            try:
                time.sleep(0.1)

                r = requests.get(url)
                data = r.json()
                df = pd.DataFrame(data['result'])

                length = df.shape[0]

                if length == 10000:
                    lst.loc[lst['root'] == root, token_type] = -2
                    lst.to_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv')
                    done += 1
                    print(f'{root}_{chain} find {length} connected wallets with {token_type}, Process: {done}/{total}.')
                    continue

                if length == 0:
                    lst.loc[lst['root'] == root, token_type] = 0
                    lst.to_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv')
                    done += 1
                    print(f'{root}_{chain} find {length} connected wallets with {token_type}, Process: {done}/{total}.')
                    continue

                lst.loc[lst['root'] == root, token_type] = length
                df.to_csv(f'{RD}connected_accounts/csv/{root}_{chain}_{token_type}.csv', index=False)
                lst.to_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv', index=False)
                done += 1
                print(f'{root}_{chain} find {length} connected wallets with {token_type}, Process: {done}/{total}.') 

            except Exception as e:
                print(f'Errors happen: {e}')
                continue
# Out:
# 0xf4784c0ea2b64359a5b0d94129e28a81cf80a9d6_binance find 27 connected wallets with normal_token, Process: 1/5978.
# 0x7431d90db56582a6c6a4c0eb375db20289d2264c_binance find 20 connected wallets with normal_token, Process: 2/5978.
# 0x57b85ec48b6c8acf7fc396d459d1c71f8a6064bf_binance find 946 connected wallets with normal_token, Process: 3/5978.
# 0x180d285dd9a4fec0d95ed94436f722f0ff01cfb2_binance find 14 connected wallets with normal_token, Process: 4/5978.
# 0xa10fe5280e10e0a43e083098763bc02696d00119_binance find 46 connected wallets with normal_token, Process: 5/5978.
# 0xf3cd7261f2515c815d2bc0bc509ff38e45e05d6d_binance find 886 connected wallets with normal_token, Process: 6/5978.
# 0xb3b5df01697fcbdb6ad506dcb5d15c7b7dfd747a_binance find 129 connected wallets with normal_token, Process: 7/5978.
# 0xae588526d6867075419ba0f80a9e4ba1f9109e71_binance find 508 connected wallets with normal_token, Process: 8/5978.
# ...

# %% [markdown]
# # More than 10000

# %% [markdown]
# ## Transaction Filter List

# %%
# chains = ['ethereum', 'binance', 'avalanche', 'fantom', 'polygon']

# for chain in chains:
#     df = pd.read_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv')
#     df.to_csv(f'{RD}connected_accounts/10000filter/root_{chain}_list.csv', index=False)

# %% [markdown]
# ## Remove Null Address

# %%
chains = ['ethereum', 'binance', 'avalanche']

for chain in chains:
    df = pd.read_csv(f'{RD}connected_accounts/10000filter/root_{chain}_list.csv')
    df.loc[df['root'] == '0x0000000000000000000000000000000000000000']
    # df.to_csv(f'{RD}connected_accounts/10000filter/root_{chain}_list.csv', index=False)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []

# %%
chains = [('ethereum', 15500001), ('binance', 20500001), ('avalanche', 18500001), ('fantom', 45000001), ('polygon', 35000001)]
token_types = ['normal_token', 'nft_token']

for chain in chains:
    for token_type in token_types:
        
        lst = pd.read_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv')
        lst.loc[lst[token_type] == -2]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
#       Unnamed: 0                                        root  normal_token  \
# 4903        4904  0x23ef42f28bb38e54996a9660c929922b26cc3d06            -2
#
#       nft_token
# 4903          0
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
#      Unnamed: 0                                        root  normal_token  \
# 292         292  0x808996b4af65c316a027a9ada0d395afc27c7385            -2
#
#      nft_token
# 292          0
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# Empty DataFrame
# Columns: [root, normal_token, nft_token]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## To do

# %%
chains = [('ethereum', 15500001), ('binance', 20500001), ('avalanche', 18500001), ('fantom', 45000001), ('polygon', 35000001)]
token_types = ['normal_token', 'nft_token']

for chain in chains:
    for token_type in token_types:
        
        lst = pd.read_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv')
        lst.loc[lst[token_type] == -2]
        num = lst.loc[lst[token_type] == -2].shape[0]
        print(f'{chain[0]},{token_type}:{num}')
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# ethereum,normal_token:0
# Empty DataFrame
# Columns: [Unnamed: 0, root, normal_token, nft_token]
# Index: []
# ethereum,nft_token:0
#       Unnamed: 0                                        root  normal_token  \
# 1156        1156  0x458b14915e651243acf89c05859a22d5cff976a6            -2
# 1381        1381  0xdfb8603d947ab42fb76eb3bb14d9dde4334130d2            -2
# 1598        1598  0xa5025faba6e70b84f74e9b1113e5f7f4e7f4859f            -2
# 1621        1621  0xd152f549545093347a162dce210e7293f1452150            -2
# 1625        1625  0x16b9a82891338f9ba80e2d6970fdda79d1eb0dae            -2
# 1737        1737  0xeb8c29674ba8c124b62c5789bca5f1dfcb43cbee            -2
# 1747        1747  0x59c7f0a0016eace17d0b57a695b8b7088096bf5e            -2
# 1842        1842  0x5e820fe0733a72554ba88fda9e430e50ebc25e00            -2
# 1864        1864  0x66268537ce69c47ec5b7e921fd9dcc68a7073220            -2
# ...

# %% [markdown]
# ## Remove Contract

# %%
chains = [('ethereum', 15500001), ('binance', 20500001), ('avalanche', 18500001), ('fantom', 45000001), ('polygon', 35000001)]
token_types = ['normal_token', 'nft_token']

chain_info = chains[0]
token_type = token_types[0]

chain = chain_info[0]
root = '0xa99c602037f8e85a44bbe88f3c0ee3af60345b9b'

if chain == 'ethereum': rpc = 'https://rpc.ankr.com/eth'
if chain == 'binance': rpc = 'https://bscrpc.com'
if chain == 'avalanche': rpc = 'https://api.avax.network/ext/bc/C/rpc'
if chain == 'fantom': rpc = 'https://rpc.ftm.tools'
if chain == 'polygon': rpc = 'https://polygon-rpc.com'

w3 = Web3(Web3.HTTPProvider(rpc))
w3.eth.getCode(w3.toChecksumAddress(root))
w3.eth.getCode(w3.toChecksumAddress(root)).hex() != '0x'
# Out:
# HexBytes('0x')
# False

# %%
lst = pd.read_csv(f'{RD}connected_accounts/10000filter/root_{chain_info[0]}_list.csv')
todo = lst.loc[lst[token_type] == -2]['root'].values
todo
lst.loc[lst[token_type] == -2]
# Out:
# array(['0x129f027a491d96abced68cc30976797a42987303'], dtype=object)
#                                           root  normal_token  nft_token
# 14  0x129f027a491d96abced68cc30976797a42987303            -2          0

# %%
# lst.loc[lst['root'] == '0xd152f549545093347a162dce210e7293f1452150', 'normal_token'] = 0
lst.loc[[True if i in todo else False for i in lst['root']]]
# lst = lst.loc[lst['root']!='0x000000000000000000000000000000000000dead']
# Out:
#                                           root  normal_token  nft_token
# 4   0xd152f549545093347a162dce210e7293f1452150             0          1
# 14  0x129f027a491d96abced68cc30976797a42987303            -2          0

# %%
chain_info[0]
# Out:
# 'polygon'

# %%
lst.to_csv(f'{RD}connected_accounts/10000filter/root_{chain_info[0]}_list.csv', index=False)

# %% [markdown]
# ## Find Block

# %%
def search_standard_txn(chain_info, token_info, root, startblock, endblock):
    if (chain_info == 'ethereum')&(token_type == 'normal_token'):
        url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

    if (chain_info == 'ethereum')&(token_info == 'nft_token'):     
        url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

    if (chain_info == 'binance')&(token_info == 'normal_token'):    
        url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

    if (chain_info == 'binance')&(token_info == 'nft_token'): 
        url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

    if (chain_info == 'avalanche')&(token_info == 'normal_token'): 
        url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

    if (chain_info == 'avalanche')&(token_info == 'nft_token'):     
        url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

    if (chain_info == 'fantom')&(token_info == 'normal_token'):    
        url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

    if (chain_info == 'fantom')&(token_info == 'nft_token'):  
        url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

    if (chain_info == 'polygon')&(token_info == 'normal_token'): 
        url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'

    if (chain_info == 'polygon')&(token_info == 'nft_token'): 
        url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={startblock}\
&endblock={endblock}\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'
                
    r = requests.get(url)
    data = r.json()
    df = pd.DataFrame(data['result'])
    length = len(data['result'])
    
    return df, length

# %%
def search_txn(chain_info, token_info, root, block, transaction):
    if (chain_info == 'ethereum')&(token_type == 'normal_token'):
        url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

    if (chain_info == 'ethereum')&(token_info == 'nft_token'):     
        url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

    if (chain_info == 'binance')&(token_info == 'normal_token'):    
        url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

    if (chain_info == 'binance')&(token_info == 'nft_token'): 
        url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

    if (chain_info == 'avalanche')&(token_info == 'normal_token'): 
        url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

    if (chain_info == 'avalanche')&(token_info == 'nft_token'):     
        url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

    if (chain_info == 'fantom')&(token_info == 'normal_token'):    
        url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

    if (chain_info == 'fantom')&(token_info == 'nft_token'):  
        url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

    if (chain_info == 'polygon')&(token_info == 'normal_token'): 
        url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'

    if (chain_info == 'polygon')&(token_info == 'nft_token'): 
        url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+transaction-1}\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'
                
    r = requests.get(url)
    data = r.json()
    df = pd.DataFrame(data['result'])
    length = len(data['result'])
    
    return df, length

# %%
chains = [('ethereum', 15500001), ('binance', 20500001), ('avalanche', 18500001), ('fantom', 45000001), ('polygon', 35000001)]
token_types = ['normal_token', 'nft_token']

for chain in chains:
    for token_type in token_types:
        
        # lst = pd.read_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv')
        lst = pd.read_csv(f'{WD}/connected_wallet/list/root_list.csv')
        # for idx, row in lst.loc[lst[token_type] == -2].iterrows():
        for idx, row in lst.loc[((lst['normal_token'] == -1)|(lst['nft_token'] == -1))&(lst['chain'] == chain[0])].iterrows():
            try: 
                root = row['root']
                
                dfs = []
                endblock = chain[1]
                transaction = 100000

                for block in range(0, endblock, transaction):

                    df, length = search_txn(chain[0], token_type, root, block, transaction)

    #                 if length == 10000:
    #                     print('reach the 10,000 limit!')
    #                     subtransaction = transaction
    #                     subendblock = block+transaction+1

    #                     while (True):
    #                         subtransaction = int(subtransaction/10)
    #                         print(f'narrower, subtransaction:{subtransaction}')
    #                         dfss = []

    #                         for subblock in range(block, subendblock, subtransaction):
    #                             df, sublength = search_txn(chain[0], token_type, root, subblock, subtransaction)
    #                             print(f'narrow: {subblock}/{subendblock}{chain[0]} chain {token_type} data!sublength:{sublength}.')
    #                             if sublength == 10000: break
    #                             dfss.append(df)

    #                         if sublength != 10000:
    #                             df = pd.concat(dfss)
    #                             break

    #                         if subtransaction == 1: break

                    if length == 10000:
                        print('reach the 10,000 limit')
                        subtransaction = transaction
                        subbeginblock = block
                        subendblock = block+transaction+1
                        zero_sum = 0
                        no_info = False
                        
                        dfss = []

                        while (True):
                            subtransaction = int(subtransaction/10)
                            print(f'narrower, {subtransaction/10}')

                            for subblock in range(subbeginblock, subendblock, subtransaction):
                                df, sublength = search_txn(chain[0], token_type, root, subblock, subtransaction)
                                print(f'narrow: {subblock}/{subendblock}{chain[0]} chain {token_type} data!sublength:{sublength}.')
                                
                                ## still need to be narrower
                                if sublength == 10000:
                                    subbeginblock = subblock
                                    break

                                dfss.append(df)
                                
                                ## left transactions are less then 10000
                                if sublength == 0:
                                    zero_sum += 1
                                else:
                                    zero_sum = 0
                                    
                                if zero_sum == 10:
                                    df, sublength = search_standard_txn(chain[0], token_type, root, subblock, subendblock)
                                    if sublength != 10000:
                                        dfss.append(df)
                                        no_info = True
                                        break
                                    else:
                                        zero_sum = 0
                                
                            if (sublength != 10000)|(no_info == True):
                                df = pd.concat(dfss)
                                print('no narrower transaction exist.')
                                length = df.shape[0]
                                break

                            if subtransaction == 1: break   


                    dfs.append(df)
                    print(f'sucessfully get {block}/{endblock}{chain[0]} chain {token_type} data!length:{length}.')

                dfs = pd.concat(dfs)
                total_length = dfs.shape[0]
                # lst.loc[lst['root'] == root, token_type] = total_length
                dfs.to_csv(f'{RD}connected_accounts/csv/{root}_{chain[0]}_{token_type}.csv', index=False)
                # lst.to_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv', index=False)
                print(f'***{root} done，total length: {total_length}***')
            except Exception as e:
                print(e)
print('done')
# Out:
# sucessfully get 0/15500001ethereum chain normal_token data!length:0.
# sucessfully get 100000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 200000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 300000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 400000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 500000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 600000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 700000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 800000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 900000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 1000000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 1100000/15500001ethereum chain normal_token data!length:0.
# sucessfully get 1200000/15500001ethereum chain normal_token data!length:0.
# ...

# %% [markdown]
# ## Find Block: Debug

# %%
chains = [('ethereum', 15500001), ('binance', 20500001), ('avalanche', 18500001), ('fantom', 45000001), ('polygon', 35000001)]
token_types = ['normal_token', 'nft_token']
debug = 0

for chain in chains:
    for token_type in token_types:
        
        # lst = pd.read_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv')
        lst = pd.read_csv(f'{WD}/connected_wallet/list/root_list.csv')
        # for idx, row in lst.loc[lst[token_type] == -2].iterrows():
        
        
        
        for idx, row in lst.loc[((lst['normal_token'] == -1)|(lst['nft_token'] == -1))&(lst['chain'] == chain[0])].iterrows():
            try: 
                root = row['root']
                
                if debug == 0:
                    if root == '0xd61da9986c2e31210344f45e93b6574fa61e31bf':
                        debug = 1
                    continue
                    
                
                dfs = []
                endblock = chain[1]
                transaction = 100000

                for block in range(0, endblock, transaction):

                    df, length = search_txn(chain[0], token_type, root, block, transaction)

    #                 if length == 10000:
    #                     print('reach the 10,000 limit!')
    #                     subtransaction = transaction
    #                     subendblock = block+transaction+1

    #                     while (True):
    #                         subtransaction = int(subtransaction/10)
    #                         print(f'narrower, subtransaction:{subtransaction}')
    #                         dfss = []

    #                         for subblock in range(block, subendblock, subtransaction):
    #                             df, sublength = search_txn(chain[0], token_type, root, subblock, subtransaction)
    #                             print(f'narrow: {subblock}/{subendblock}{chain[0]} chain {token_type} data!sublength:{sublength}.')
    #                             if sublength == 10000: break
    #                             dfss.append(df)

    #                         if sublength != 10000:
    #                             df = pd.concat(dfss)
    #                             break

    #                         if subtransaction == 1: break

                    if length == 10000:
                        print('reach the 10,000 limit')
                        subtransaction = transaction
                        subbeginblock = block
                        subendblock = block+transaction+1
                        zero_sum = 0
                        no_info = False
                        
                        dfss = []

                        while (True):
                            subtransaction = int(subtransaction/10)
                            print(f'narrower, {subtransaction/10}')

                            for subblock in range(subbeginblock, subendblock, subtransaction):
                                df, sublength = search_txn(chain[0], token_type, root, subblock, subtransaction)
                                print(f'narrow: {subblock}/{subendblock}{chain[0]} chain {token_type} data!sublength:{sublength}.')
                                
                                ## still need to be narrower
                                if sublength == 10000:
                                    subbeginblock = subblock
                                    break

                                dfss.append(df)
                                
                                ## left transactions are less then 10000
                                if sublength == 0:
                                    zero_sum += 1
                                else:
                                    zero_sum = 0
                                    
                                if zero_sum == 10:
                                    df, sublength = search_standard_txn(chain[0], token_type, root, subblock, subendblock)
                                    if sublength != 10000:
                                        dfss.append(df)
                                        no_info = True
                                        break
                                    else:
                                        zero_sum = 0
                                
                            if (sublength != 10000)|(no_info == True):
                                df = pd.concat(dfss)
                                print('no narrower transaction exist.')
                                length = df.shape[0]
                                break

                            if subtransaction == 1: break   


                    dfs.append(df)
                    print(f'sucessfully get {block}/{endblock}{chain[0]} chain {token_type} data!length:{length}.')

                dfs = pd.concat(dfs)
                total_length = dfs.shape[0]
                # lst.loc[lst['root'] == root, token_type] = total_length
                dfs.to_csv(f'{RD}connected_accounts/csv/{root}_{chain[0]}_{token_type}.csv', index=False)
                # lst.to_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv', index=False)
                print(f'***{root} done，total length: {total_length}***')
            except Exception as e:
                print(e)
print('done')
# Out:
# sucessfully get 0/20500001binance chain normal_token data!length:0.
# sucessfully get 100000/20500001binance chain normal_token data!length:0.
# sucessfully get 200000/20500001binance chain normal_token data!length:0.
# sucessfully get 300000/20500001binance chain normal_token data!length:0.
# sucessfully get 400000/20500001binance chain normal_token data!length:0.
# sucessfully get 500000/20500001binance chain normal_token data!length:0.
# sucessfully get 600000/20500001binance chain normal_token data!length:0.
# sucessfully get 700000/20500001binance chain normal_token data!length:0.
# sucessfully get 800000/20500001binance chain normal_token data!length:0.
# sucessfully get 900000/20500001binance chain normal_token data!length:0.
# sucessfully get 1000000/20500001binance chain normal_token data!length:0.
# sucessfully get 1100000/20500001binance chain normal_token data!length:0.
# sucessfully get 1200000/20500001binance chain normal_token data!length:0.
# ...

# %% [markdown]
# # Test and Grave

# %% [markdown]
# ## API

# %% [markdown]
# ### ERC-20

# %%
url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokentx\
&address=0x5CcCE837B41Dbd2ad74882889749517935741390\
&startblock=13630000\
&endblock=13640000\
&page=1\
&offset=10000\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

r = requests.get(url)
r.status_code
data = r.json()
pd.DataFrame(data['result'])
# Out:
# 200
#      blockNumber   timeStamp  \
# 0       13633328  1637157173
# 1       13633328  1637157173
# 2       13633328  1637157173
# 3       13633328  1637157173
# 4       13633328  1637157173
# ...          ...         ...
# 5995    13634866  1637177451
# 5996    13634866  1637177451
# 5997    13634866  1637177451
# 5998    13634866  1637177451
# 5999    13634866  1637177451
#
#                                                                     hash  \
# 0     0x25976cc679909ab8a78cd2a953b2687134b21d13acb9236be907b648060d02a1
# 1     0x25976cc679909ab8a78cd2a953b2687134b21d13acb9236be907b648060d02a1
# 2     0x25976cc679909ab8a78cd2a953b2687134b21d13acb9236be907b648060d02a1
# 3     0x25976cc679909ab8a78cd2a953b2687134b21d13acb9236be907b648060d02a1
# 4     0x25976cc679909ab8a78cd2a953b2687134b21d13acb9236be907b648060d02a1
# ...                                                                  ...
# 5995  0x2c976d94e9056eae1b49c76ea1847567afe296dc33331caeb59ddba8a0a455b6
# ...

# %% [markdown]
# ### ERC-721

# %%
url = 'https://api.polygonscan.com/api\
# ?module=account\
&action=tokennfttx\
&address=0x9b09783e11ce3b5abc4cd180cc0ca6ff366a0893\
&startblock=0\
&endblock=99999999\
&page=1\
&offset=10000\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'

r = requests.get(url)
r.status_code
data = r.json()
pd.DataFrame(data['result'])
# Out:
# 200
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Identify Contract

# %%
from web3 import Web3
w3 = Web3(Web3.HTTPProvider('https://rpc.ankr.com/eth'))
w3.eth.getCode(w3.toChecksumAddress('0xa99c602037f8e85a44bbe88f3c0ee3af60345b9b'))
# Out:
# HexBytes('0x')

# %% [markdown]
# ### Web Crawler

# %%
# chains = ['ethereum', 'binance', 'avalanche', 'fantom', 'polygon']
# token_types = ['normal_token', 'nft_token']

# chain = chains[0]
# token_type = token_types[0] 

# lst = pd.read_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv')
# done = lst.loc[(lst[token_type] != -1)].shape[0]
# total = lst.shape[0]

# for idx, row in lst.loc[(lst[token_type] == -1)].iterrows():
    
#     root = row['root']
    
#     if (chain == 'ethereum')&(token_type == 'normal_token'):
#         url = f'https://api.etherscan.io/api\
# ?module=account\
# &action=tokentx\
# &address={root}\
# &page=1\
# &offset=10000\
# &startblock=0\
# &endblock=99999999\
# &sort=asc\
# &apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'
                        
#     if (chain == 'ethereum')&(token_type == 'nft_token'):     
#         url = f'https://api.etherscan.io/api\
# ?module=account\
# &action=tokennfttx\
# &address={root}\
# &page=1\
# &offset=10000\
# &startblock=0\
# &endblock=99999999\
# &sort=asc\
# &apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'
        
#     if (chain == 'binance')&(token_type == 'normal_token'):    
#         url = 'https://api.bscscan.com/api\
# ?module=account\
# &action=tokentx\
# &address=0x9451feb8a9d64a64b10ff94db109417fed5fccc4\
# &page=1\
# &offset=10000\
# &startblock=0\
# &endblock=999999999\
# &sort=asc\
# &apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'
        
#     if (chain == 'binance')&(token_type == 'nft_token'): 
#     url = 'https://api.bscscan.com/api\
# ?module=account\
# &action=tokennfttx\
# &address=0x9451feb8a9d64a64b10ff94db109417fed5fccc4\
# &page=1\
# &offset=10000\
# &startblock=0\
# &endblock=999999999\
# &sort=asc\
# &apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'
    
#     if (chain == 'avalanche')&(token_type == 'normal_token'): 
#     url = 'https://api.snowtrace.io/api\
# ?module=account\
# &action=tokentx\
# &address=0xdb72cda0312928845ed33beca90bc3cfc2dd0449\
# &page=1\
# &offset=10000\
# &startblock=0\
# &endblock=999999999\
# &sort=asc\
# &apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'
    
#     if (chain == 'avalanche')&(token_type == 'nft_token'):     
#     url = 'https://api.snowtrace.io/api\
# ?module=account\
# &action=tokennfttx\
# &address=0xdb72cda0312928845ed33beca90bc3cfc2dd0449\
# &page=1\
# &offset=10000\
# &startblock=0\
# &endblock=999999999\
# &sort=asc\
# &apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'
    
#     if (chain == 'fantom')&(token_type == 'normal_token'):    
#     url = 'https://api.ftmscan.com/api\
# ?module=account\
# &action=tokentx\
# &address=0x1fc31cadf521d57c117575950031468f365a3b78\
# &startblock=0\
# &endblock=99999999\
# &page=1\
# &offset=10000\
# &sort=asc\
# &apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'
    
#     if (chain == 'fantom')&(token_type == 'nft_token'):  
#     url = 'https://api.ftmscan.com/api\
# ?module=account\
# &action=tokennfttx\
# &address=0x1fc31cadf521d57c117575950031468f365a3b78\
# &startblock=0\
# &endblock=99999999\
# &page=1\
# &offset=10000\
# &sort=asc\
# &apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'
    
#     if (chain == 'polygon')&(token_type == 'normal_token'): 
#     url = 'https://api.polygonscan.com/api\
# ?module=account\
# &action=tokentx\
# &address=0x9b09783e11ce3b5abc4cd180cc0ca6ff366a0893\
# &startblock=0\
# &endblock=99999999\
# &page=1\
# &offset=10000\
# &sort=asc\
# &apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'
    
#     if (chain == 'polygon')&(token_type == 'nft_token'): 
#     url = 'https://api.polygonscan.com/api\
# ?module=account\
# &action=tokennfttx\
# &address=0x9b09783e11ce3b5abc4cd180cc0ca6ff366a0893\
# &startblock=0\
# &endblock=99999999\
# &page=1\
# &offset=10000\
# &sort=asc\
# &apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'    
        
#     try:
#         time.sleep(2)
        
#         r = requests.get(url)
#         data = r.json()
#         df = pd.DataFrame(data['result'])
        
#         length = df.shape[0]
        
#         if length == 10000:
#             lst.loc[lst['root'] == root, token_type] = -2
#             lst.to_csv(f'{RD}connected_accounts/list/root_{chain}_list')
#             done += 1
#             print(f'{chain} find {length} connected wallets with {token_type}, Process: {done}/{total}.')
#             continue
        
#         if length == 0:
#             lst.loc[lst['root'] == root, token_type] = 0
#             lst.to_csv(f'{RD}connected_accounts/list/root_{chain}_list')
#             done += 1
#             print(f'{chain} find {length} connected wallets with {token_type}, Process: {done}/{total}.')
#             continue
            
#         lst.loc[lst['root'] == root, token_type] = length
#         df.to_csv(f'{RD}connected_accounts/csv/{root}_{chain}_{token_type}.csv', index=False)
#         lst.to_csv(f'{RD}connected_accounts/list/root_{chain}_list.csv', index=False)
#         done += 1
#         print(f'{chain} find {length} connected wallets with {token_type}, Process: {done}/{total}.') 
        
#     except Exception as e:
#         print(f'Errors happen: {e}')
#         continue

# %% [markdown]
# ### More than 10000

# %%
chains = [('ethereum', 15500000), ('binance', 20500000), ('avalanche', 18500000), ('fantom', 45000000), ('polygon', 35000000)]
token_types = ['normal_token', 'nft_token']
error = 0

for chain in chains:
    for token_type in token_types:
        
        lst = pd.read_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv')
        for idx, row in lst.loc[lst[token_type] == -2].iterrows():
            root = row['root']
            
            dfs = []
            endblock = chain[1]
            transaction = 10000

            for block in range(0, endblock, transaction):
                
            if (chain == 'ethereum')&(token_type == 'normal_token'):
                url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

            if (chain == 'ethereum')&(token_type == 'nft_token'):     
                url = f'https://api.etherscan.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=SE4Y8HN6P577WGIJSM8561XVS3279RCYAS'

            if (chain == 'binance')&(token_type == 'normal_token'):    
                url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

            if (chain == 'binance')&(token_type == 'nft_token'): 
                url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'

            if (chain == 'avalanche')&(token_type == 'normal_token'): 
                url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

            if (chain == 'avalanche')&(token_type == 'nft_token'):     
                url = f'https://api.snowtrace.io/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=3T6M6ZYKPZAKHFUDR5ZXNFCNPQH6TFPDMV'

            if (chain == 'fantom')&(token_type == 'normal_token'):    
                url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

            if (chain == 'fantom')&(token_type == 'nft_token'):  
                url = f'https://api.ftmscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=SATQZK8FZ54E91DER6QA8Z549M7Z5TI89B'

            if (chain == 'polygon')&(token_type == 'normal_token'): 
                url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokentx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'

            if (chain == 'polygon')&(token_type == 'nft_token'): 
                url = f'https://api.polygonscan.com/api\
# ?module=account\
&action=tokennfttx\
&address={root}\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=RQ81U42M4YSGZJ1DVTG8TCX64F446C4W8H'
                
                r = requests.get(url)
                data = r.json()
                df = pd.DataFrame(data['result'])
                length = len(data['result'])
                if length == 10000:
                    error += 1
                    print(f'{block}/{endblock}区块链上溢出!')

                dfs.append(df)
                print(f'成功获取{block}/{endblock}区块链上的数据! 溢出次数为{error}')
            dfs = pd.concat(dfs)
            length = dfs.shape[0]
            lst.loc[lst['root'] == root, token_type] = length
            df.to_csv(f'{RD}connected_accounts/csv/{root}_{chain[0]}_{token_type}.csv', index=False)
            lst.to_csv(f'{RD}connected_accounts/10000filter/root_{chain[0]}_list.csv', index=False)
            print(f'***{root}数据获取完成，长度为{length}***')
            
print('done')
# Out:
# '0x5ccce837b41dbd2ad74882889749517935741390'
# '0xa99c602037f8e85a44bbe88f3c0ee3af60345b9b'
# '0x165cd37b4c644c2921454429e7f9358d18a45e14'
# '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'
# '0x2d407ddb06311396fe14d4b49da5f0471447d45c'
# '0xd1917932a7db6af687b523d5db5d7f5c2734763f'
# '0x87fadf44bc06a8c9ae965edfe72ee703cef703c5'
# '0xbe7c3dc615245d3404858386ce6e2443ddd4bc25'
# '0x55ac81186e1a8454c79ad78c615c43f54f87403b'
# '0x0000000000000000000000000000000000000000'
# '0xae5f8d8b97867dbb1f278127706e1095811d5bf5'
# '0x1882c296ebfa916a0ad194cfa0094c5e0086ba03'
# '0x57dbae4b73455bc0d3e892ae57779160961f0f03'
# '0x75110a3c9833e3546b7b20b85f1d0a1e0843e390'
# '0x7d9c3bd1eb0b0a8921fab9c57e26e05518d87b4d'
# '0x26b007d1d0976228d71ee4edc6fe7993616c04bc'
# '0xddf1d0f361ae9444020fcfa905acb4faff420bdd'
# '0xd2f1cd52475d2d46fc4cb214238391aec862941b'
# '0xf91bf03020978842cffa7946b0d561e61a08bf37'
# '0x1e8f7bfdcf6d95eea81e039234624fa6b78bd389'
# '0xdbe3e700ab26cbf3523d850b5d892fd17e0ce343'
# ...

# %%
dfs = []
error = 0
starttime = datetime.datetime.now()
endblock = 20500000
transaction = 10000

for block in range(0, endblock, transaction):
    
    url = f'https://api.bscscan.com/api\
# ?module=account\
&action=tokentx\
&address=0x1882c296ebfa916a0ad194cfa0094c5e0086ba03\
&page=1\
&offset=10000\
&startblock={block}\
&endblock={block+9999}\
&sort=asc\
&apikey=6ECWSUUEEJ8FJH4GHKSS7F58Z8NY45DJJ8'
    
    r = requests.get(url)
    data = r.json()
    df = pd.DataFrame(data['result'])
    length = len(data['result'])
    if length == 10000:
        error += 1
        print(f'{block}/{endblock}区块链上溢出!')
    
    dfs.append(df)
    
    endtime = datetime.datetime.now()
    duration = (endtime-starttime).seconds / 60
    lefttime = (duration / (block + 1)) * (18900000- block)
    print(f'成功获取{block}/{endblock}区块链上的数据! 预估还需要{lefttime}分钟, 数据长度为{length}, 溢出次数为{error}')
    
dfs
# Out:
# 成功获取0/20500000区块链上的数据! 预估还需要0.0分钟, 数据长度为0, 溢出次数为0
# 成功获取10000/20500000区块链上的数据! 预估还需要31.480185314801854分钟, 数据长度为0, 溢出次数为0
# 成功获取20000/20500000区块链上的数据! 预估还需要31.465093411996065分钟, 数据长度为0, 溢出次数为0
# 成功获取30000/20500000区块链上的数据! 预估还需要31.448951701609946分钟, 数据长度为0, 溢出次数为0
# 成功获取40000/20500000区块链上的数据! 预估还需要31.43254751964534分钟, 数据长度为0, 溢出次数为0
# 成功获取50000/20500000区块链上的数据! 预估还需要31.416038345899747分钟, 数据长度为0, 溢出次数为0
# 成功获取60000/20500000区块链上的数据! 预估还需要31.399476675388744分钟, 数据长度为0, 溢出次数为0
# 成功获取70000/20500000区块链上的数据! 预估还需要26.899615719775433分钟, 数据长度为0, 溢出次数为0
# 成功获取80000/20500000区块链上的数据! 预估还需要27.445490264705025分钟, 数据长度为0, 溢出次数为0
# 成功获取90000/20500000区块链上的数据! 预估还需要27.86635704047733分钟, 数据长度为0, 溢出次数为0
# 成功获取100000/20500000区块链上的数据! 预估还需要28.19971800281997分钟, 数据长度为0, 溢出次数为0
# 成功获取110000/20500000区块链上的数据! 预估还需要28.469438156622818分钟, 数据长度为0, 溢出次数为0
# 成功获取120000/20500000区块链上的数据! 预估还需要26.083115974033547分钟, 数据长度为0, 溢出次数为0
# 成功获取130000/20500000区块链上的数据! 预估还需要26.47030920274972分钟, 数据长度为0, 溢出次数为0
# ...
